# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandramani05/Data-Science-Project-Spotify-API-ANALYSIS/blob/main/Data_Science_Project_Spotify_API_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import os

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import seaborn as sns

# %%
import spotipy
import time
import requests
from spotipy.oauth2 import SpotifyClientCredentials 
client_id = "c32e413cd15b402e9261265d1b2ba75f"
client_secret = "f2d9660fa85e4a8f90a8a0151d55568c"
sp = spotipy.Spotify(
    auth_manager=SpotifyClientCredentials(
        client_id=client_id,
        client_secret=client_secret,
    ),
    requests_timeout=10,
    retries=10,
)
sp

# %%
songs_list = []

years = ['1995','1996','1997','1998','1999','2000','2001',
              '2002','2003','2004','2005','2006','2007','2008',
              '2009','2010','2011','2012','2013','2014','2015','2016','2017','2018'
              ,'2019','2020','2021','2022']
              
for year in years : 
    for i in range(0,100,50):
        track_results = sp.search(q='year:'+year,type='track',limit=50, offset=i)
        for i, t in enumerate(track_results['tracks']['items']):
            artist = sp.artist(t["artists"][0]["external_urls"]["spotify"])
            album = sp.album(t["album"]["external_urls"]["spotify"])
            songs_data = {
                    'id':t['id'],
                    'song name':t['name'],
                    'artist name':t['artists'][0]['name'],
                    'artist popularity' : artist['popularity'],
                    'artist genres':artist["genres"],
                    'album genres': album["genres"],
                    'release_date':t['album']['release_date'],
                    'song duration':t['duration_ms'],
                    'song popularity' : t['popularity'],
                }
            songs_list.append(songs_data)
df_songs = pd.DataFrame(songs_list)

df_songs = pd.DataFrame(songs_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-002e1ee7277d> in <module>
#      10         track_results = sp.search(q='year:'+year,type='track',limit=50, offset=i)
#      11         for i, t in enumerate(track_results['tracks']['items']):
# ---> 12             artist = sp.artist(t["artists"][0]["external_urls"]["spotify"])
#      13             album = sp.album(t["album"]["external_urls"]["spotify"])
#      14             songs_data = {
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in artist(self, artist_id)
#     364
#     365         trid = self._get_id("artist", artist_id)
# --> 366         return self._get("artists/" + trid)
#     367
#     368     def artists(self, artists):
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
# --> 242                 timeout=self.requests_timeout, **args
#     243             )
#     244
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497                     decode_content=False,
#     498                     retries=self.max_retries,
# --> 499                     timeout=timeout,
#     500                 )
#     501
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     874
#     875             response.drain_conn()
# --> 876             retries.sleep(response)
#     877             log.debug("Retry: %s", url)
#     878             return self.urlopen(
#
# /usr/local/lib/python3.7/dist-packages/urllib3/util/retry.py in sleep(self, response)
#     426
#     427         if self.respect_retry_after_header and response:
# --> 428             slept = self.sleep_for_retry(response)
#     429             if slept:
#     430                 return
#
# /usr/local/lib/python3.7/dist-packages/urllib3/util/retry.py in sleep_for_retry(self, response)
#     405         retry_after = self.get_retry_after(response)
#     406         if retry_after:
# --> 407             time.sleep(retry_after)
#     408             return True
#     409
#
# KeyboardInterrupt:

# %% [markdown]
# #Importing Packages

# %%
df_songs.to_csv("Songs_Data.csv")
df_songs
# Out:
#                           id                         song name  \
# 0     3EaJDYHA0KnX88JvDhL9oa                          Dark Red
# 1     3AVrVz5rK8Hrqo9YGiVGN5                        Apocalypse
# 2     7KA4W4McWYRpgf0fWsJZWB  See You Again (feat. Kali Uchis)
# 3     5BbdKBZO0TH0GhfxUfyhL9                         Freestyle
# 4     5TXDeTFVRVY7Cvt0Dw4vWW                           Revenge
# ...                      ...                               ...
# 5995  2NATVR6A6K2uMLeo4KQOo0               On Top Of The World
# 5996  2rqB2I2stqNPaVBaObZnDx                          Speak Up
# 5997  769Ld8demNhMgVLAQcjTDn                      sun and moon
# 5998  6Z1bV93BP95h4YjIavrQPf            Dancin’ In The Country
# 5999  6MlIIJwO4FxnOlrpOrS4hU           METAMORPHOSIS - Sped Up
#
#                artist name           artist_name  \
# 0               Steve Lacy            Steve Lacy
# 1     Cigarettes After Sex  Cigarettes After Sex
# 2       Tyler, The Creator    Tyler, The Creator
# 3                 Lil Baby              Lil Baby
# 4             XXXTENTACION          XXXTENTACION
# ...                    ...                   ...
# 5995       Imagine Dragons       Imagine Dragons
# 5996              Is0kenny              Is0kenny
# 5997                 anees                 anees
# 5998         Tyler Hubbard         Tyler Hubbard
# 5999            INTERWORLD            INTERWORLD
#
#                                           artist genres  \
# 0                                        [afrofuturism]
# 1     [ambient pop, dream pop, el paso indie, pop, s...
# 2                                        [hip hop, rap]
# 3                    [atl hip hop, atl trap, rap, trap]
# 4                              [emo rap, miami hip hop]
# ...                                                 ...
# 5995                                [modern rock, rock]
# 5996                                        [anime rap]
# 5997                                                 []
# 5998                    [contemporary country, country]
# 5999                                                 []
#
#                                             preview_url album genres  \
# 0     https://p.scdn.co/mp3-preview/f1cb993064ab6a04...           []
# 1     https://p.scdn.co/mp3-preview/d8d24e7154833c65...           []
# 2     https://p.scdn.co/mp3-preview/e6c4c9656721fe0a...           []
# 3     https://p.scdn.co/mp3-preview/1dc65cb338a941a0...           []
# 4     https://p.scdn.co/mp3-preview/f5096665f4f47142...           []
# ...                                                 ...          ...
# 5995  https://p.scdn.co/mp3-preview/6faaf69000610901...           []
# 5996  https://p.scdn.co/mp3-preview/91493769a5dd8d2f...           []
# 5997  https://p.scdn.co/mp3-preview/241bb6f64b825dff...           []
# 5998  https://p.scdn.co/mp3-preview/1eefc045cf5fb506...           []
# 5999  https://p.scdn.co/mp3-preview/00f1438802072f5e...           []
#
#      release_date                                          song link  \
# 0      2017-02-20  https://open.spotify.com/track/3EaJDYHA0KnX88J...
# 1      2017-06-09  https://open.spotify.com/track/3AVrVz5rK8Hrqo9...
# 2      2017-07-21  https://open.spotify.com/track/7KA4W4McWYRpgf0...
# 3      2017-12-01  https://open.spotify.com/track/5BbdKBZO0TH0Ghf...
# 4      2017-08-25  https://open.spotify.com/track/5TXDeTFVRVY7Cvt...
# ...           ...                                                ...
# 5995   2022-11-04  https://open.spotify.com/track/2NATVR6A6K2uMLe...
# 5996   2022-10-04  https://open.spotify.com/track/2rqB2I2stqNPaVB...
# 5997   2022-04-06  https://open.spotify.com/track/769Ld8demNhMgVL...
# 5998   2022-08-19  https://open.spotify.com/track/6Z1bV93BP95h4Yj...
# 5999   2022-06-24  https://open.spotify.com/track/6MlIIJwO4FxnOlr...
#
#       song duration  song popularity
# 0            173104               86
# 1            290146               82
# 2            180386               84
# 3            162053               83
# 4            120026               87
# ...             ...              ...
# 5995         192800                2
# 5996         104960               67
# 5997         151507               75
# 5998         179645               67
# 5999         110936               77
#
# [6000 rows x 11 columns]
